# %% [markdown]
# # 00 Preparation

# %%
# IMPORT LIBRARIES
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score, confusion_matrix

# %% [markdown]
# # 01 Load Data

# %%
# LOAD DATA
df = pd.read_csv("03_buys_product.csv")
df
# Out:
#      Age  Income  IsStudent  BuysProduct
# 0     56   53467          1            1
# 1     46   38328          0            1
# 2     32   18987          1            0
# 3     60   73871          0            1
# 4     25   37399          0            1
# ..   ...     ...        ...          ...
# 295   52   81040          1            1
# 296   33   43016          0            1
# 297   58   38960          1            1
# 298   53   48591          0            1
# 299   50   82641          0            1
#
# [300 rows x 4 columns]

# %%
# FEATURES UND ZIELVARIALE
x = df.drop(["BuysProduct"], axis =1)
y = df["BuysProduct"]

# %% [markdown]
# # 02 Split Data

# %%
# SPLIT in 70% TRAIN und 30% TEST
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1234, stratify=y)
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1234,)

# %%
# TRAINING MIT LOGISTIC REGRESSION
lr = LogisticRegression(max_iter=500)
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# # 03 Modell Trainieren

# %%
# VORHERSAGEN MACHEN
y_pred = lr.predict(x_test)

# %% [markdown]
# # 04 Modell Evaluieren

# %%
# KENNZAHLEN BERECHNEN
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}\nRecall: {recall:.2f}\nPrecisiob: {precision:.2f}\nF1-Score: {f1:.2f}\n")
# Out:
# Accuracy: 0.92
# Recall: 0.97
# Precisiob: 0.93
# F1-Score: 0.95

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion Matrix berechnen
cm = confusion_matrix(y_test, y_pred)

# Confusion Matrix visualisieren
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Positiv', 'Negativ'], yticklabels=['Positiv', 'Negativ'])
plt.xlabel('Vorhergesagte Klasse')
plt.ylabel('Tatsächliche Klasse')
plt.title('Confusion Matrix')
plt.show()
