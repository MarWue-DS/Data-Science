# %% [markdown]
# # 🛠️ Definition Preprocessing
# ### Daten laden

# %%
# IMPORT LIBRRIES
import pandas as pd

# LOAD DATA
df = pd.read_csv("03_titanic_data.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Nicht skalierte numerische Werte können in vielen maschinellen Lernalgorithmen zu Problemen führen, insbesondere bei Algorithmen, die auf Distanzen und/oder Gradienten(abstiegen) basieren. Hier sind einige spezifische Herausforderungen, die durch nicht skalierte Merkmale entstehen können:
# Probleme durch nicht skalierte Werte
#
#     Vergleichbarkeit der Merkmale:
#         Ohne Skalierung können Merkmale mit größeren Wertebereichen die Algorithmen dominieren. Dies kann dazu führen, dass Merkmale mit kleinen Wertebereichen, die möglicherweise ebenso wichtig sind, vernachlässigt werden.
#     Konvergenzgeschwindigkeit:
#         Bei Modellen, die auf Gradientenabstieg basieren (wie lineare oder logistische Regression), kann die Konvergenz wesentlich langsamer sein, wenn die Merkmale unterschiedliche Skalierungen aufweisen. Nicht skalierte Merkmale bedingen unterschiedlich steile Gradienten, was die Modellanpassung beeinträchtigt.
#     Effektivität von Distanzbasierten Algorithmen:
#         Algorithmen wie k-Nearest Neighbors oder k-Means Clustering basieren auf Entfernungsmaßen. Unterschiede in der Skalierung können dazu führen, dass die Ergebnisse fehlerhaft sind, da sich der Algorithmus zu stark auf die Merkmale mit größeren Skalen konzentriert.
#     Numerische Stabilität:
#         Sehr große oder sehr kleine Werte können numerische Probleme in Algorithmen verursachen, die Matrixoperationen verwenden, wie z.B. Support Vector Machines und neuronale Netze.
#
# Lösung: Feature Scaling
# Um diese Probleme zu beheben, wendest du Techniken zur Skalierung von Features an:
#
#     Min-Max-Skalierung: Skaliert die Features auf einen bestimmten Bereich (üblicherweise [0, 1]).
#     python
#
# from sklearn.preprocessing import MinMaxScaler
#
# scaler = MinMaxScaler()
# scaled_data = scaler.fit_transform(data)
#
# Standardisierung (Z-Score-Normalisierung): Setzt die Merkmale in Bezug auf ihren Mittelwert bei 0 und die Standardabweichung bei 1.
# python
#
#     from sklearn.preprocessing import StandardScaler
#
#     scaler = StandardScaler()
#     standardized_data = scaler.fit_transform(data)
#
# Beide Methoden haben ihre spezifischen Anwendungsfälle und Vorzüge, abhängig von den Eigenschaften der Daten und den Anforderungen des verwendeten Algorithmus.

# %% [markdown]
# Mit Hilfe des Chatbots identifizeirt, dass:
#
# 1. Fehlende Werte behandelt werden sollte
# Spalten mit fehlenden Werten: Age, Cabin, Embarked
# - Age: Fehlende Werte könnten durch den Durchschnitt oder den Median der Altersangaben ersetzt werden.
# - Cabin: Viele Werte fehlen in dieser Spalte. Du könntest entweder die gesamte Spalte weglassen oder nur den Buchstaben (für das Deck) extrahieren, sofern genügend Informationen vorhanden sind.
# - Embarked: Fehlende Werte können mit dem häufigsten Wert (Modus) aufgefüllt werden.
#
# 2. Umwandlung von Kategorien
# - Sex: In numerische Werte umwandeln, z. B. male zu 1 und female zu 0.
# - Embarked: In numerische Werte umwandeln (z. B. S zu 0, C zu 1, Q zu 2). Alternativ können One-Hot-Encoding oder dummies verwendet werden.
#
# 3. Normalisierung oder Standardisierung
# Numerische Spalten: Age, Fare
# - Die Standardisierung oder Normalisierung dieser Spalten kann die Modellentwicklung verbessern, insbesondere wenn unterschiedliche Skalen benutzt werden.
#
# 4. Feature Engineering
# - Title aus Name extrahieren: Möglicherweise kannst du einen Titel aus dem Namen extrahieren, der zusätzliche Informationen liefert (z. B. Mr., Mrs., Miss.).
# - Familiengröße berechnen: Eine neue Spalte basierend auf SibSp (Anzahl der Geschwister/Ehepartner an Bord) und Parch (Anzahl der Eltern/Kinder an Bord), um die Gesamtfamiliengröße zu berechnen: FamilySize = SibSp + Parch + 1.
#
# 5. Unwichtige Spalten entfernen
# - PassengerId, Name, Ticket: Diese Spalten enthalten möglicherweise keine nützlichen Informationen für die Modellentwicklung und könnten entfernt werden, es sei denn, sie werden beim Feature Engineering verwendet.
